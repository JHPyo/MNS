# %%
import pandas as pd
import numpy as np

full_name = r'F:\dLight Representative\FP\L125M7D4_Avoidance+_onset.csv'
data = pd.read_csv(full_name, header = 0)

# %%
data
# Out:
#            Time         1         2         3         4         5         6  \
# 0      0.018457 -0.803758  0.124471 -0.637294  0.983000 -0.932696  0.527481
# 1      0.059472 -0.256693 -0.008548 -0.203538  1.144523 -0.081146  0.001281
# 2      0.100488  0.077438 -0.233753 -0.114126 -0.642163 -1.729238  1.350485
# 3      0.141503  0.116089  0.352717 -0.154263  0.015830 -0.958340  1.887979
# 4      0.182519  0.192388  1.248537 -0.692112  1.450207  0.971117  2.047940
# ...         ...       ...       ...       ...       ...       ...       ...
# 1458  59.818917  0.945680  0.298281 -0.605547  2.115836  3.127810  1.071529
# 1459  59.859932  1.273255  0.548523 -0.633884  2.691293  2.550544  0.941453
# 1460  59.900948  0.584488  0.508583 -0.524839  4.090240  2.163656  0.245753
# 1461  59.941963  0.341955  1.589352 -0.761628  2.591767  1.333476  0.598711
# 1462  59.980928 -0.240972  1.214753 -0.647412  3.273513  3.727307  0.280808
#
# ...

# %%
tdata = data.loc[(data.Time<40),]

# %%
select = tdata[['Time','4']]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

x_data = []
y_data = []

fig = plt.figure(figsize=(30,6), dpi =300, facecolor ="black")  
ax = fig.subplots()
ax.set_xlim(0,40)
ax.set_ylim(-2,15)
line, = ax.plot (0,0, 'w', linewidth=3.0)
ax.patch.set_facecolor('black')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=40)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=40)  # y축 눈금 폰트 크기

x = np.linspace(0,40,975)
y = list(select["6"])

def animation_frame(i):
    x_data.append(x[i])
    y_data.append(y[i])
    line.set_xdata(x_data)
    line.set_ydata(y_data)
    return line,

plt.show()
animation = FuncAnimation(fig, func=animation_frame, frames = 975, interval = 41)
animation.save("test.mp4")

# %%
select = tdata[['Time','6']]

# %%
tdata
# Out:
#           Time         1         2         3         4         5         6  \
# 0     0.018457 -0.803758  0.124471 -0.637294  0.983000 -0.932696  0.527481
# 1     0.059472 -0.256693 -0.008548 -0.203538  1.144523 -0.081146  0.001281
# 2     0.100488  0.077438 -0.233753 -0.114126 -0.642163 -1.729238  1.350485
# 3     0.141503  0.116089  0.352717 -0.154263  0.015830 -0.958340  1.887979
# 4     0.182519  0.192388  1.248537 -0.692112  1.450207  0.971117  2.047940
# ..         ...       ...       ...       ...       ...       ...       ...
# 970  39.803399  1.127099  2.394399  0.773281  3.261698  3.503159  2.835572
# 971  39.844415  1.241864  1.759424  0.570646  3.137162  4.945516  2.367709
# 972  39.885430  1.130973  2.378770  0.706163  3.867460  3.894026  3.856997
# 973  39.926446  0.924847  1.614801  0.858051  3.689252  3.336692  2.257887
# 974  39.967461  1.079045  1.924941  0.194038  3.117945  2.247519  2.097950
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(select["Time"],select["6"])

# %%
np.linspace(0,40,975)

# %%
A = pd.read_csv(r'C:\Users\GoNe\Desktop\Tools\Python\velocity.csv', header = None)
A=A.transpose()
A.plot.line()
# Out:
# <AxesSubplot: >

# %%
Time2=np.linsp

# %%
A['Time']=Time2

# %%
plt.subplot(2, 1, 1)
plt.plot(tdata['Time'],tdata['6'])
plt.title('Doapmine dF/F')
plt.xlabel('time (s)')
plt.ylabel('dF/F')

plt.subplot(2, 1, 2)
plt.plot(A['Time'],A[0],'r')
plt.title('Velocity')
plt.xlabel('time (s)')
plt.ylabel('Velocity')


plt.tight_layout()

plt.savefig('twograph.pdf',transparent=True, dpi=300)

# %%
A
# Out:
#              0       Time
# 0     1.460293   0.000000
# 1     1.460293   0.033361
# 2     2.455678   0.066722
# 3     2.505139   0.100083
# 4     2.085797   0.133445
# ...        ...        ...
# 1195  6.285219  39.866555
# 1196  1.609729  39.899917
# 1197  0.743456  39.933278
# 1198  5.920571  39.966639
# 1199  2.089228  40.000000
#
# [1200 rows x 2 columns]

# %%
plt.plot(A['Time'], A[0])

plt.plot(tdata['Time'], tdata['6'])



plt.show()

# %%
tdata
# Out:
#           Time         1         2         3         4         5         6  \
# 0     0.018457 -0.803758  0.124471 -0.637294  0.983000 -0.932696  0.527481
# 1     0.059472 -0.256693 -0.008548 -0.203538  1.144523 -0.081146  0.001281
# 2     0.100488  0.077438 -0.233753 -0.114126 -0.642163 -1.729238  1.350485
# 3     0.141503  0.116089  0.352717 -0.154263  0.015830 -0.958340  1.887979
# 4     0.182519  0.192388  1.248537 -0.692112  1.450207  0.971117  2.047940
# ..         ...       ...       ...       ...       ...       ...       ...
# 970  39.803399  1.127099  2.394399  0.773281  3.261698  3.503159  2.835572
# 971  39.844415  1.241864  1.759424  0.570646  3.137162  4.945516  2.367709
# 972  39.885430  1.130973  2.378770  0.706163  3.867460  3.894026  3.856997
# 973  39.926446  0.924847  1.614801  0.858051  3.689252  3.336692  2.257887
# 974  39.967461  1.079045  1.924941  0.194038  3.117945  2.247519  2.097950
#
# ...
